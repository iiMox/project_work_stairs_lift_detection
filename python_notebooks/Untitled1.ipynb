# %%
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

# %%
cm_8s = [[1633,10,19,70,61],[30,175,0,30,0],[36,3,177,0,9],[83,1,0,562,10],[101,0,0,15,609]]

# %%
cm_4s = [[3340,39,54,216,175],[147,304,4,9,1],[173,15,321,1,9],[236,0,0,1061,71],[281,0,0,89,1153]]

# %%
labels = ['Null', 'lift down', 'lift up', 'stairs down', 'stairs up']

# %%
plt.figure(figsize=(10,7))
sns.heatmap(cm_4s, annot=True,fmt='d', cmap='Blues', xticklabels=labels, yticklabels=labels, cbar=False, annot_kws={"size": 14})
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.tight_layout()
plt.savefig("confusion_matrix_4s.pdf", format='pdf')
plt.show()
